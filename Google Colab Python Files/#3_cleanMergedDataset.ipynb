# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
gptData = pd.read_csv('/content/drive/MyDrive/datasets/chatGPT_Vader_n_Blob_Sentiment.csv')

# %%
gptData.head()
# Out:
#                                     Processed_Tweets  Vader_Polarity  \
# 0             openai’s gpt-4 just got supercharged!           0.0000
# 1  "classical art" is struggling - not changed th...         -0.2500
# 2  alibaba invites businesses to trial 'chatgpt r...          0.0000
# 3  trying to stop students from using and is like...         -0.2263
# 4  i asked chatgpt's ai chatbot how can i earn cr...          0.0000
#
#    Blob_Polarity
# 0            0.0
# 1            0.2
# 2            0.0
# 3            0.1
# 4            0.0

# %%
import re
# cleaning the merged dataset
def pre_process(text):
    # Removes links
    text = re.sub('http://\S+|https://\S+', '', text)
    text = re.sub('http[s]?://\S+', '', text)
    text = re.sub(r"http\S+", "", text)

    text = re.sub('&amp', 'and', text)
    text = re.sub('&lt', '<', text)
    text = re.sub('&gt', '>', text)

    # Removes new line characters
    text = re.sub('[\r\n]+', ' ', text)

    # Removes special characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)

    # Removes multiple space characters
    text = re.sub('\s+',' ', text)

    # Converting to lowercase
    text = text.lower()
    return text

# %%
gptData['Processed_Tweets'] = gptData['Processed_Tweets'].apply(pre_process)

# %%
gptData.head()
# Out:
#                                     Processed_Tweets  Vader_Polarity  \
# 0                openais gpt4 just got supercharged           0.0000
# 1  classical art is struggling not changed the fa...         -0.2500
# 2  alibaba invites businesses to trial chatgpt ri...          0.0000
# 3  trying to stop students from using and is like...         -0.2263
# 4  i asked chatgpts ai chatbot how can i earn cry...          0.0000
#
#    Blob_Polarity
# 0            0.0
# 1            0.2
# 2            0.0
# 3            0.1
# 4            0.0

# %%
gptData.to_csv('/content/drive/MyDrive/datasets/VaderAndBlobSentiment.csv')
