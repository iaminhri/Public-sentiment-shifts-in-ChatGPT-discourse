# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
gptData = pd.read_csv('/content/drive/MyDrive/datasets/ChatGPT.csv')
# Out:
# <ipython-input-3-19db0e4d3825>:1: DtypeWarning: Columns (0,6,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   gptData = pd.read_csv('/content/drive/MyDrive/datasets/ChatGPT.csv')

# %%
gptData2 = pd.read_csv('/content/drive/MyDrive/datasets/cleaned_dataset.csv')

# %%
gptData2.head(30000)
# Out:
#            tweet_id              tweet_created             tweet_extracted  \
# 0      1.642739e+18  2023-04-03 03:59:28+00:00  2023-04-08 01:06:52.504868
# 1      1.642920e+18  2023-04-03 15:59:59+00:00  2023-04-08 01:07:04.742617
# 2      1.642708e+18  2023-04-03 01:59:25+00:00  2023-04-08 01:06:50.638068
# 3      1.642859e+18  2023-04-03 11:59:28+00:00  2023-04-08 01:07:00.375167
# 4      1.642874e+18  2023-04-03 12:59:26+00:00  2023-04-08 01:07:01.437161
# ...             ...                        ...                         ...
# 20540  1.657023e+18  2023-05-12 13:59:56+00:00  2023-05-14 20:23:13.630164
# 20541  1.657008e+18  2023-05-12 12:59:14+00:00  2023-05-14 20:23:12.370904
# 20542  1.656872e+18  2023-05-12 03:59:37+00:00  2023-05-14 20:23:02.568671
# 20543  1.657143e+18  2023-05-12 21:59:28+00:00  2023-05-14 20:23:23.672531
# 20544  1.657038e+18  2023-05-12 14:59:34+00:00  2023-05-14 20:23:14.758872
#
#                                                     text lang  \
# ...

# %%
# renaming the column labels.
gptData2.rename(columns={'tweet_created': 'Date'}, inplace=True)
gptData2.rename(columns={'text': 'Tweet'}, inplace=True)
gptData2.rename(columns={'user_username': 'User'}, inplace=True)
gptData2.rename(columns={'user_location': 'Location'}, inplace=True)
gptData2.rename(columns={'user_description': 'Description'}, inplace=True)
gptData2.rename(columns={'user_created': 'UserCreated'}, inplace=True)
gptData2.rename(columns={'user_followers_count': 'UserFollowers'}, inplace=True)
gptData2.rename(columns={'user_verified': 'UserVerified'}, inplace=True)
gptData2.rename(columns={'retweet_count': 'Retweets'}, inplace=True)
gptData2.rename(columns={'like_count': 'Likes'}, inplace=True)
gptData2.rename(columns={'tweet_id': 'Unnamed: 0'}, inplace=True)

# %%
gptData.head(1)
# Out:
#   Unnamed: 0                       Date  \
# 0          0  2023-04-08 03:33:13+00:00
#
#                                                Tweet  \
# 0  #ChatGPT If only there were a movie or somethi...
#
#                                                  Url           User  \
# 0  https://twitter.com/kirbydjohnson/status/16445...  kirbydjohnson
#
#                  UserCreated UserVerified  UserFollowers  UserFriends  \
# 0  2012-07-29 22:57:46+00:00        False           50.0         76.0
#
#   Retweets Likes Location Description
# 0      0.0     0      NaN         NaN

# %%
gptData2.head(1)
# Out:
#      Unnamed: 0                       Date             tweet_extracted  \
# 0  1.642739e+18  2023-04-03 03:59:28+00:00  2023-04-08 01:06:52.504868
#
#                                                Tweet lang     user_id  \
# 0  rt darrelllerner chatgpt plugins are the faste...   en  2383245894
#
#   user_name             User Location             Description  \
# 0        pk  pradeep42329225    India  💐💐।।जय श्री महाकाल।।💐💐
#
#                  UserCreated  UserFollowers  user_following_count  \
# 0  2014-03-11 06:04:10+00:00          269.0                4141.0
#
#    user_tweet_count UserVerified  source  Retweets  Likes  reply_count  \
# 0            3816.0        False     NaN     628.0    0.0          0.0
#
#    impression_count
# 0               0.0

# %%
# drop - user_id, user_name, user_tweet_count, user_following_count, source, reply_count, impression_count
gptData2.drop(columns=['tweet_extracted'], inplace=True)
gptData2.drop(columns=['user_id'], inplace=True)
gptData2.drop(columns=['user_name'], inplace=True)
gptData2.drop(columns=['user_tweet_count'], inplace=True)
gptData2.drop(columns=['user_following_count'], inplace=True)
gptData2.drop(columns=['source'], inplace=True)
gptData2.drop(columns=['impression_count'], inplace=True)
gptData2.drop(columns=['reply_count'], inplace=True)
gptData2.drop(columns=['lang'], inplace=True)

# %%
gptData.head(1)
# Out:
#   Unnamed: 0                       Date  \
# 0          0  2023-04-08 03:33:13+00:00
#
#                                                Tweet  \
# 0  #ChatGPT If only there were a movie or somethi...
#
#                                                  Url           User  \
# 0  https://twitter.com/kirbydjohnson/status/16445...  kirbydjohnson
#
#                  UserCreated UserVerified  UserFollowers  UserFriends  \
# 0  2012-07-29 22:57:46+00:00        False           50.0         76.0
#
#   Retweets Likes Location Description
# 0      0.0     0      NaN         NaN

# %%
gptData2.head(1)
# Out:
#      Unnamed: 0                       Date  \
# 0  1.642739e+18  2023-04-03 03:59:28+00:00
#
#                                                Tweet             User  \
# 0  rt darrelllerner chatgpt plugins are the faste...  pradeep42329225
#
#   Location             Description                UserCreated  UserFollowers  \
# 0    India  💐💐।।जय श्री महाकाल।।💐💐  2014-03-11 06:04:10+00:00          269.0
#
#   UserVerified  Retweets  Likes
# 0        False     628.0    0.0

# %%
gptData.drop(columns=['UserFriends'], inplace=True)
gptData.drop(columns=['Url'], inplace=True)

# %%
gptData.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Tweet', 'User', 'UserCreated', 'UserVerified',
#        'UserFollowers', 'Retweets', 'Likes', 'Location', 'Description'],
#       dtype='object')

# %%
gptData2.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Tweet', 'User', 'Location', 'Description',
#        'UserCreated', 'UserFollowers', 'UserVerified', 'Retweets', 'Likes'],
#       dtype='object')

# %%
gptData2.head(30000)
# Out:
#          Unnamed: 0                       Date  \
# 0      1.642739e+18  2023-04-03 03:59:28+00:00
# 1      1.642920e+18  2023-04-03 15:59:59+00:00
# 2      1.642708e+18  2023-04-03 01:59:25+00:00
# 3      1.642859e+18  2023-04-03 11:59:28+00:00
# 4      1.642874e+18  2023-04-03 12:59:26+00:00
# ...             ...                        ...
# 20540  1.657023e+18  2023-05-12 13:59:56+00:00
# 20541  1.657008e+18  2023-05-12 12:59:14+00:00
# 20542  1.656872e+18  2023-05-12 03:59:37+00:00
# 20543  1.657143e+18  2023-05-12 21:59:28+00:00
# 20544  1.657038e+18  2023-05-12 14:59:34+00:00
#
#                                                    Tweet             User  \
# 0      rt darrelllerner chatgpt plugins are the faste...  pradeep42329225
# 1      get an intelligent chatbot for your website in...     ArrheniusLey
# 2      hey guys zenithswap has launched at just 55000...  KiarostamiBeing
# 3      rt sinsonetwork now join sinso datalandchatgpt...         holymoko
# ...

# %%
import re

# %%
merged_dataset = pd.concat([gptData, gptData2], axis=0, ignore_index=True) # dataset merged

# %%
print("Length of Dataframe 1: ",len(gptData))
print("Length of Dataframe 2: ",len(gptData2))
print("Length of Merged Dataframe: ",len(gptData) + len(gptData2))
print("Length of Merged Dataframe: ",len(merged_dataset))
# Out:
# Length of Dataframe 1:  478347
# Length of Dataframe 2:  20545
# Length of Merged Dataframe:  498892
# Length of Merged Dataframe:  498892

# %%
# checking if data is merged properly.
# Printing the first few rows of dataset1's 'Unnamed: 0' column
print("Dataset 1 'Unnamed: 0' column:")
print(gptData['Unnamed: 0'].head())

# Printing the last few rows of dataset1's 'Unnamed: 0' column
print("\nDataset 1 'Unnamed: 0' column:")
print(gptData['Unnamed: 0'].tail())

# Printing the first few rows of dataset2's 'Unnamed: 0' column
print("\nDataset 2 'Unnamed: 0' column:")
print(gptData2['Unnamed: 0'].head())

# Printing the first few rows of dataset2's 'Unnamed: 0' column
print("\nDataset 2 'Unnamed: 0' column:")
print(gptData2['Unnamed: 0'].tail())

# Printing the first few rows of the merged 'Unnamed: 0' column
print("\nMerged 'Unnamed: 0' column:")
print(merged_dataset['Unnamed: 0'].head())

# Printing the last few rows of the merged 'Unnamed: 0' column
print("\nMerged 'Unnamed: 0' column:")
print(merged_dataset['Unnamed: 0'].tail())
# Out:
# Dataset 1 'Unnamed: 0' column:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Unnamed: 0, dtype: object
#
# Dataset 1 'Unnamed: 0' column:
# 478342    478261
# 478343    478262
# 478344    478263
# 478345    478264
# 478346    478265
# Name: Unnamed: 0, dtype: object
#
# Dataset 2 'Unnamed: 0' column:
# 0    1.642739e+18
# 1    1.642920e+18
# 2    1.642708e+18
# 3    1.642859e+18
# 4    1.642874e+18
# Name: Unnamed: 0, dtype: float64
#
# Dataset 2 'Unnamed: 0' column:
# 20540    1.657023e+18
# 20541    1.657008e+18
# 20542    1.656872e+18
# 20543    1.657143e+18
# 20544    1.657038e+18
# Name: Unnamed: 0, dtype: float64
#
# Merged 'Unnamed: 0' column:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Unnamed: 0, dtype: object
#
# Merged 'Unnamed: 0' column:
# 498887    1657022799515463680.0
# 498888    1657007524602691584.0
# 498889    1656871727866220288.0
# 498890    1657143481557557248.0
# 498891    1657037808610017280.0
# Name: Unnamed: 0, dtype: object

# %%
merged_dataset.head(535070)
# Out:
#                    Unnamed: 0                       Date  \
# 0                           0  2023-04-08 03:33:13+00:00
# 1                           1  2023-04-08 03:32:16+00:00
# 2                           2  2023-04-08 03:32:05+00:00
# 3                           3  2023-04-08 03:31:08+00:00
# 4                           4  2023-04-08 03:30:51+00:00
# ...                       ...                        ...
# 498887  1657022799515463680.0  2023-05-12 13:59:56+00:00
# 498888  1657007524602691584.0  2023-05-12 12:59:14+00:00
# 498889  1656871727866220288.0  2023-05-12 03:59:37+00:00
# 498890  1657143481557557248.0  2023-05-12 21:59:28+00:00
# 498891  1657037808610017280.0  2023-05-12 14:59:34+00:00
#
#                                                     Tweet             User  \
# 0       #ChatGPT If only there were a movie or somethi...    kirbydjohnson
# 1       Workshop Description: In this workshop, you wi...    UniversityWeb
# ...

# %%
merged_dataset.to_csv("/content/drive/MyDrive/datasets/current_13_04_Dataset/newDatasetCreated2.csv", index=False) # file export.
